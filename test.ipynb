# %%
import sys
import os

# %%
from subgrapher.datasets import SubgraphDataset
from subgrapher.graph_sampler import sample_neg

# %%
# Initialize the subgraph dataset with seed weights
subgraph_dataset = SubgraphDataset(
    data_dir='./data/FB15k237',
    dataset_name='FB15k237',
    split='train',  # enum: 'train' or 'valid' or 'test'
    num_neg_samples=1,  # number of negative samples per positive sample
    max_links=10000  # maximum number of links to consider
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Initialize the subgraph dataset with seed weights
# ----> 2 subgraph_dataset = SubgraphDataset(
#       3     data_dir='./data/FB15k237',
#       4     dataset_name='FB15k237',
#       5     split='train',  # enum: 'train' or 'valid' or 'test'
#       6     num_neg_samples=1,  # number of negative samples per positive sample
#       7     max_links=10000  # maximum number of links to consider
#       8 )
#
# File d:\Work\LilacEmpre\MTCH\subgrapher\datasets.py:72, in SubgraphDataset.__init__(self, data_dir, dataset_name, split, num_neg_samples, max_links)
#      67     self.triplets = np.array([[self.entity2id[t[0]], self.entity2id[t[2]], self.relation2id[t[1]]]
#      68                             for t in [line.split() for line in f.read().split('\n')[:-1]]])
#      70 # Sample negative examples
#      71 self.pos_triplets, self.neg_triplets = sample_neg(
# ---> 72     self.adj_list,
#      73     self.triplets,
#      74     self.num_neg_samples,
#      75     max_size=self.max_links
#      76 )
#
# AttributeError: 'SubgraphDataset' object has no attribute 'adj_list'

# %%
for i in range(len(subgraph_dataset)):
    subgraph, label = subgraph_dataset[i]
